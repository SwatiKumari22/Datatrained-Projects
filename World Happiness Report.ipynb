# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Given is the dataframe with 153 rows and 12 columns. The dataframe is about the Happiness score of different countries.The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# There are 158 rows and 12 columns in this dataset

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# The Columns Are As Such:
#
# Country: Name of the country.
#
# Region: Region the country belongs to
#
# Happiness Rank: A rank given to the country to describe its happiness level.
#
# Happiness Score: A metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest."
#
# Stndard Error:
#
# Economy (GDP per Capita): The extent to which GDP contributes to the calculation of the Happiness Score.
#
# Family: The extent to which Family contributes to the calculation of the Happiness Score
#
# Health (Life Expectancy): The extent to which Life expectancy contributed to the calculation of the Happiness Score
#
# Freedom: The extent to which Freedom contributed to the calculation of the Happiness Score.
#
# Trust (Government Corruption): The extent to which Perception of Corruption contributes to Happiness Score.
#
# Generosity:
#
# Dystopia Residual: The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
#
# Happiness Score: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country which is predicted through Happiness Score.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# There is no null values in any columns.
# Country and Region columns has data of object dtypes, Happiness rank is of integer dtype and rest other columns are having float type of data.

# %% [markdown]
# ## EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There is no null values in the data. We can check this in heat map also.

# %%
#To check missing values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# OBSERVATIONS:
# Data has no missing values.
# If there were any, it would have been visible in different colour shade.

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %% [markdown]
# Happiness Score scale ranges from 2.839 to 7.587.
# 7.587 is the highest score so that country will have 1st rank and 2.839 is the lowest happiness score so that country will be at lowest rank.

# %% [markdown]
# ### Visualizing Categorical data with respect to target variables.

# %% [markdown]
# #### Scatterplot

# %%
sns.scatterplot(x='Country',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %% [markdown]
# Country is well distributed between 0 to 160 with no outliers.

# %%
sns.scatterplot(x='Region',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Happiness Rank',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Happiness Score'>

# %% [markdown]
# We can see Happiness rank is !st for highest Happiness Score and it decreases as the score decreases.

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %% [markdown]
# We can see Standard Error is well distributed between 0.02 and 0.07. So many outliers are there beyond that.

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %% [markdown]
# We can see Trust (Government Corruption) is well distributed between 0 and 0.2. So many outliers are there beyond that.

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %% [markdown]
# Family is well distributed between 0.6 and 14.So many outliers are there before that range.

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %% [markdown]
# Generosity is well distributed between 0 and 0.5.Few outliers are there beyond that.

# %% [markdown]
# ### Vizualising numerical variables
# Let's make a pairplot of all the numeric variables

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# #### Changing Categorical variables to integer type

# %%
# Since 'COuntry' and 'Region' Are of Categorical dtype.So we are applying ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder
encode=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=encode.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# ### Describing the Dataset with all the coulmns

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# Key Observations:
#
# 1 In all the columns, there is not much difference between mean and median(50%).So the data might not be much skewed.
#
# 2 There is also not much difference difference between 75% and max value in any of the columns other than Standard Error And Trust.
#
# 3 The 1 and 2 observations suggest that there might be some outliers present in data of Standard Error and Trust columns.
#
# 4 Other than these two, there are not any extreme outliers present in any of the columns.

# %%
plt.figure(figsize=(8,6))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=14)
plt.yticks(fontsize=10)
plt.title('Variables summary')
plt.show()

# %% [markdown]
# ### To Check Correlation

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:
#
# 1. Dark shades are highly correlated.
#
# 2. Happiness Score is maximum corelated with Economy(GDP Per Capita).
#
# 3. Happiness Score is negetively correlated with Happiness rank,Region and Standard Error.
#
# 4. Economy(GDP Per Capita) has 78% correlation with target(Happiness Score),which is considered a strong bond.
#
# 5. Family(74%),Health(Life Expectancy)(72%),Freedom(58%) also has very good bond with the target(Happiness Score) , which means they also contribute a lot in Happiness Score.
#
# 6. It is less correlated with Region(-18%) and Standard Error(-18%).These are having very weak bonds with Happiness Score.
#
# 7. Happiness Rank is showing highly negatively correlated(-99%) with Happiness Score because lowest the rank value means more happy the country is. So more the Happiness Score will be.
#
# Max correlated : Family
#
# Min Correlated : Happiness Rank

# %% [markdown]
# ### Outliers Checking

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(14,12))
# Out:
# Country                             AxesSubplot(0.125,0.536818;0.110714x0.343182)
# Region                           AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# Happiness Rank                   AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# Happiness Score                  AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# Standard Error                   AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.789286,0.536818;0.110714x0.343182)
# Family                                 AxesSubplot(0.125,0.125;0.110714x0.343182)
# Health (Life Expectancy)            AxesSubplot(0.257857,0.125;0.110714x0.343182)
# Freedom                             AxesSubplot(0.390714,0.125;0.110714x0.343182)
# Trust (Government Corruption)       AxesSubplot(0.523571,0.125;0.110714x0.343182)
# Generosity                          AxesSubplot(0.656429,0.125;0.110714x0.343182)
# ...

# %% [markdown]
# From the above box plots we can clearly see that there are so many outliers in the data of columns[' Standard Error' and 'Trust(Government Corruption)'].
# Few outliers are there in the data of columns['Family', 'Generosity' and 'Happiness Score'].
# No outliers are present in other columns.

# %% [markdown]
# ### Check for Skewness

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# ### To check the distribution of skewness(Normal Distribution Curve)

# %%
sns.distplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Density'>

# %% [markdown]
# the data in column['Region'] is highly skewed.

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %% [markdown]
# The data in column['Standard error'] is highly skewed to the right because of outliers.

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %% [markdown]
# The data in column['Family'] is skewed towards left side bacause of the outliers present.

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %% [markdown]
# The data in column['Trust(Government Corruption'] is highly skewed to the right because of outliers.

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# The data in column['Generosity'] is skewed to the right because of few outliers.outliers.

# %% [markdown]
# #### The normal distribution shows that the data is skewed.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Since column[Standard Error'] is highly negatively correlated with target variable['Happiness Score']. Also these are a lot of outliers present in it. And the data is not normalized. So we will drop this column.

# %%
df=df.drop(['Standard Error'],axis=1)
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    135.0     9.0               1            7.587                   1.39651
# 1     58.0     9.0               2            7.561                   1.30232
# 2     37.0     9.0               3            7.527                   1.32548
# 3    105.0     9.0               4            7.522                   1.45900
# 4     24.0     5.0               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
df.shape
# Out:
# (158, 11)

# %% [markdown]
# ### Removing the Outliers

# %% [markdown]
# Z-Score Technique

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))
z
# Out:
# array([[1.23877001, 1.30025593, 1.72099989, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [0.44946522, 1.30025593, 1.69907456, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [0.90989302, 1.30025593, 1.67714922, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.26069514, 0.37544095, 1.67742676, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.26069514, 0.96511655, 1.69935209, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.37032081, 0.96511655, 1.72127743, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
z.shape
# Out:
# (158, 11)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64), array([ 8,  9,  5,  8, 10,  5], dtype=int64))

# %%
#z-score values through Rows and columns
z[27][8]
# Out:
# 3.1646194851713774

# %%
z[128][9]
# Out:
# 4.423261580434631

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  \
# 0      135.0     9.0               1            7.587
# 1       58.0     9.0               2            7.561
# 2       37.0     9.0               3            7.527
# 3      105.0     9.0               4            7.522
# 4       24.0     5.0               5            7.427
# ..       ...     ...             ...              ...
# 150     66.0     8.0             151            3.655
# 151     20.0     8.0             152            3.587
# 152      0.0     7.0             153            3.575
# 154     13.0     8.0             155            3.340
# 156     21.0     8.0             157            2.905
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (158, 11)
# (152, 11)

# %% [markdown]
# 6 Rows are removed

# %% [markdown]
# ### Percentage Data Loss

# %%
loss_percent=(158-152)/158*100
print(loss_percent)
# Out:
# 3.79746835443038

# %% [markdown]
# #### Model_1 is Model with outliers i.e. df and Model_2 is Model without outliers i.e. df_new. We will check for both the models.

# %% [markdown]
# ### Model_1- With Outliers

# %% [markdown]
# Dividing data in features and vectors.

# %%
xvar=df.drop("Happiness Score",axis=1)
xvar.shape
# Out:
# (158, 10)

# %%
x=xvar
y=df['Happiness Score']

# %%
x.shape
# Out:
# (158, 10)

# %%
y.shape
# Out:
# (158,)

# %% [markdown]
# #### Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.17106926,  1.24453048, -2.06341393, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [-0.3443269 ,  1.24453048, -2.00849761, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [-0.84509236,  1.24453048, -1.95857395, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [ 1.18876946, -0.30300992,  1.52535242, ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [-1.28332767,  0.95510156,  1.54254416, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 1.27672507,  0.95510156,  1.55970548, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %% [markdown]
# ### Since the target has multiple outcomes, we will use linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=33,random_state=47)

# %%
x_train.shape
# Out:
# (125, 10)

# %%
y_train.shape
# Out:
# (125,)

# %%
x_test.shape
# Out:
# (33, 10)

# %%
x_test.shape
# Out:
# (33, 10)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_train,y_train)
# Out:
# 0.9936121059630458

# %% [markdown]
# We can see lm.score is 0.99 which is a good score.

# %%
lm.coef_
# Out:
# array([ 0.00891354, -0.02001086, -0.25691607,  0.3182919 ,  0.22474297,
#         0.19029016,  0.11011934,  0.0626795 ,  0.08245049,  0.41586273])

# %%
lm.intercept_
# Out:
# 5.37772099466143

# %%
#Predict the Happiness Score 
pred=lm.predict(x_test)
print('Predicted Happiness Score',pred)
print('Actual Happiness Score',y_test)
# Out:
# Predicted Happiness Score [6.17338134 4.24429456 7.74511833 5.93801274 4.5049839  7.04458367
#  6.33748199 4.72263567 6.4761043  5.14184728 7.41897149 3.69169645
#  4.80051699 6.35613777 4.02770879 5.05864733 7.0035487  5.27223316
#  5.51957197 6.1214603  4.63538268 4.65458868 5.18838668 7.37377998
#  7.6808845  4.93358616 5.77167539 5.70367909 6.36374928 7.33871956
#  4.40966767 3.8724859  5.69639487]
# Actual Happiness Score 45     5.987
# 133    4.218
# 1      7.561
# 47     5.975
# 117    4.550
# 15     6.983
# 38     6.295
# 98     4.876
# 35     6.329
# 81     5.192
# 5      7.406
# 148    3.667
# 102    4.839
# 36     6.302
# 128    4.307
# 93     4.971
# 18     6.937
# 76     5.286
# 69     5.548
# 44     5.995
# 112    4.642
# 111    4.677
# 82     5.192
# 10     7.278
# 0      7.587
# 91     5.013
# 57     5.824
# 61     5.759
# 37     6.298
# 9      7.284
# 118    4.518
# 142    3.896
# 63     5.716
# Name: Happiness Score, dtype: float64

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 0.0711273319558467
# Mean squared error: 0.008755545568344838
# Root Mean squared error: 0.09357107228382519

# %% [markdown]
# Mean squared error and mean absolute error is very less. So we can go with this predicted values.

# %%
from sklearn.metrics import r2_score  # r2 says that what is the variance coming in y whenver inputs are changed
print(r2_score(y_test,pred))
# Out:
# 0.992656387173363

# %% [markdown]
# ### Model_2-Without Outliers

# %% [markdown]
# Dividing data in features and vectors.

# %%
xvar_new=df_new.drop("Happiness Score",axis=1)
xvar_new.shape
# Out:
# (152, 10)

# %%
x_new=xvar_new
y_new=df_new['Happiness Score']

# %%
x_new.shape
# Out:
# (152, 10)

# %%
y_new.shape
# Out:
# (152,)

# %% [markdown]
# #### Transforming Data to Remove Skewness

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x_new,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_new=sc.fit_transform(x_new)
x_new
# Out:
# array([[ 1.1887051 ,  1.23986819, -2.06118488, ...,  1.8220699 ,
#          0.65595135,  0.74453432],
#        [-0.31421047,  1.23986819, -2.00536253, ...,  0.35523024,
#          1.57166845,  1.10426166],
#        [-0.81704158,  1.23986819, -1.95460445, ...,  1.95457489,
#          0.97742359,  0.69531125],
#        ...,
#        [-2.10859031,  0.67236186,  1.5407485 , ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.51998719,  0.96090613,  1.57594638, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.26108344,  0.96090613,  1.61101853, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %% [markdown]
# #### Using Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x_new_train,x_new_test,y_new_train,y_new_test=train_test_split(x_new,y_new,test_size=33,random_state=47)

# %%
lm_new=LinearRegression()

# %%
lm_new.fit(x_new_train,y_new_train)
# Out:
# LinearRegression()

# %%
lm_new.score(x_new_train,y_new_train)
# Out:
# 0.9975153789878145

# %%
lm_new.coef_
# Out:
# array([ 0.00867341, -0.01671846, -0.516774  ,  0.21133603,  0.12700635,
#         0.12956517,  0.07413904,  0.04286734,  0.05990976,  0.27174206])

# %%
lm_new.intercept_
# Out:
# 5.434706474876329

# %%
#Predict the Happiness Score 
pred_new=lm_new.predict(x_new_test)
print('Predicted Happiness Score',pred_new)
print('Actual Happiness Score',y_new_test)
# Out:
# Predicted Happiness Score [7.29629416 7.65975954 4.79862999 7.38802315 6.98636336 4.65340489
#  5.72010219 4.29296198 4.31320237 5.97443033 4.450952   7.54805809
#  4.24868645 4.36163088 5.28559743 5.42953298 5.63535293 7.67142206
#  6.95268648 6.37188742 3.59472503 5.84749848 5.12247972 3.4171754
#  4.41061742 4.74652009 4.28836579 3.85247616 7.23131918 6.14048836
#  4.54833532 5.03162928 4.59477527]
# Actual Happiness Score 10     7.278
# 0      7.587
# 98     4.876
# 5      7.406
# 15     6.983
# 110    4.681
# 61     5.759
# 125    4.369
# 127    4.332
# 48     5.960
# 121    4.512
# 3      7.522
# 129    4.297
# 130    4.292
# 77     5.268
# 70     5.477
# 64     5.709
# 1      7.561
# 18     6.937
# 37     6.298
# 154    3.340
# 55     5.833
# 83     5.140
# 156    2.905
# 120    4.514
# 105    4.786
# 126    4.350
# 144    3.819
# 11     7.226
# 45     5.987
# 113    4.633
# 93     4.971
# 112    4.642
# Name: Happiness Score, dtype: float64

# %%
print('error_new:')
print('Mean absolute error_new:',mean_absolute_error(y_new_test,pred_new))
print('Mean squared error_new:',mean_squared_error(y_new_test,pred_new))

print('Root Mean squared error_new:',np.sqrt(mean_squared_error(y_test,pred_new)))
# Out:
# error_new:
# Mean absolute error_new: 0.06962118534277763
# Mean squared error_new: 0.013321019665519712
# Root Mean squared error_new: 1.880762077220105

# %%
from sklearn.metrics import r2_score  # r2 says that what is the variance coming in y whenver inputs are changed
print(r2_score(y_new_test,pred_new))
# Out:
# 0.991926759560788

# %% [markdown]
# #### Choosing the best model

# %% [markdown]
# As Model_1 with outliers and Model_2 without outliers are having almost same lm.score value and r2_score values, both the model is working fine.
# So we will go with Model_1 with outliers as it is not good to loose data unneccesarily.

# %% [markdown]
# ### Regularization
#
# Lasso And Ridge regression

# %%
from sklearn.linear_model import Lasso,Ridge
ls=Lasso(alpha=.0001)
#ls=Lasso(alpha=1.0) ..... Default
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9936115430927547

# %%
ls.coef_
# Out:
# array([ 0.00873871, -0.01962161, -0.26431679,  0.3157246 ,  0.22302378,
#         0.18863728,  0.10923166,  0.06183975,  0.08152919,  0.4124213 ])

# %%
rd=Ridge(alpha=0.0001)
#rd=Ridge()
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9936121059618186

# %% [markdown]
# ### Support Vector Machine model

# %%
from sklearn.svm import SVR

kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.9933048906645817
# 0.9664626051611986
# 0.9851199291754882

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}

model=Ridge()
grid= GridSearchCV(estimator=model, param_grid=alphavalue)
grid.fit(x,y)
print(grid)
print(grid.best_score_)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0.7960794350077689
# 1
# {'alpha': 1}

# %% [markdown]
# From the above linear regression of model_1,regularization model,Support Vector machine model,and Grid Search model,we can see that  lm.score, ls.score.rd.score and sv.score(linear)are coming almost same which is 0.99.
# So i am continuing with Model_1 i.e linear regression model with outliers.

# %% [markdown]
# ### Conclusion

# %%
import numpy as np
a=np.array(y_test)
Predicted=np.array(pred)
df_com=pd.DataFrame({'Original':a,'Predicted':Predicted},index=range(len(a)))
df_com
# Out:
#     Original  Predicted
# 0      5.987   6.173381
# 1      4.218   4.244295
# 2      7.561   7.745118
# 3      5.975   5.938013
# 4      4.550   4.504984
# 5      6.983   7.044584
# 6      6.295   6.337482
# 7      4.876   4.722636
# 8      6.329   6.476104
# 9      5.192   5.141847
# 10     7.406   7.418971
# 11     3.667   3.691696
# 12     4.839   4.800517
# 13     6.302   6.356138
# 14     4.307   4.027709
# 15     4.971   5.058647
# 16     6.937   7.003549
# 17     5.286   5.272233
# 18     5.548   5.519572
# 19     5.995   6.121460
# 20     4.642   4.635383
# 21     4.677   4.654589
# 22     5.192   5.188387
# 23     7.278   7.373780
# 24     7.587   7.680884
# 25     5.013   4.933586
# 26     5.824   5.771675
# 27     5.759   5.703679
# 28     6.298   6.363749
# 29     7.284   7.338720
# 30     4.518   4.409668
# 31     3.896   3.872486
# 32     5.716   5.696395

# %% [markdown]
# ### Model Saving

# %%
import pickle
filename='Predicted_World_Happiness_Score.pkl'
pickle.dump(lm,open(filename,'wb'))
